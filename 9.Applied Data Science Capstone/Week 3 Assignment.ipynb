# %%
from bs4 import BeautifulSoup
import requests
with open("List of postal codes of Canada_ M - Wikipedia.mhtml") as fp:
    soup = BeautifulSoup(fp,'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    From:
#    <saved blink="" by="">
#     Snapshot-Content-Location: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Subject: List of postal codes of Canada: M - Wikipedia
# Date: Mon, 4 May 2020 11:38:38 -0000
# MIME-Version: 1.0
# Content-Type: multipart/related;
# 	type="text/html";
# 	boundary="----MultipartBoundary--ITprJaVIjvaJjmyS5qH2mmq3om414b7Nf9j078epXV----"
#
#
# ------MultipartBoundary--ITprJaVIjvaJjmyS5qH2mmq3om414b7Nf9j078epXV----
# Content-Type: text/html
# Content-ID:
#     <frame-d20009aaec1b3d7ed3e748f851d0db5b>
#      Content-Transfer-Encoding: quoted-printable
# Content-Location: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#      <!DOCTYPE html>
#      <meta char='set=3DUTF-8"' content='3D"text/html;' http-equiv='3D"Content-Type"'/>
#      <link ccf34-fcc6-462a-9d59-333fca8271bf="" href='3D"cid:css-c6d=' rel='3D"stylesheet"' type='3D"text/css"'/>
# ...

# %%
tbody=soup.find('tbody')
print(tbody)
# Out:
# <tbody>
# <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>
# <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>
# <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park / Harbourfront
# </td></tr>
# <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor / Lawrence Heights
# </td></tr>
# <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park / Ontario Provincial Government
# </td></tr>
# <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue
# </td></tr>
# <tr>
# <td>M1B
# </td>
# <td>Scarborough
# </td>
# <td>Malvern / Rouge
# </td></tr>
# <tr>
# <td>M2B
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M3B
# </td>
# ...

# %%
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>
